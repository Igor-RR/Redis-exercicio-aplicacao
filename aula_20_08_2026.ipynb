# %% [markdown]
# <a href="https://colab.research.google.com/github/Igor-RR/Redis-exercicio-aplicacao/blob/main/aula_20_08_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Pronto para IA")

import sys

print(sys.version)
# Out:
# Pronto para IA
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
